# %% [markdown]
# # Week 2A. Python Rapid Transition
#
# BCS2143 / BIT3203 Introduction to Artificial Intelligence
#
# Run this notebook in Visual Studio Code using the `.venv` Python kernel. Predict each output before running the cell.

# %%
print('Python environment is working')

# %% [markdown]
# ## 1. Python conditions and indentation

# %%
x = 5
if x > 3:
    print('big')

# %% [markdown]
# ### Repair challenge
# Modify the value of `x` or the condition so that the programme prints `Python is useful for AI`.

# %%
x = 2
if x > 3:
    print('Python is useful for AI')

# %% [markdown]
# ## 2. Dynamic typing

# %%
value = 10
print(value, type(value))
value = 'Artificial Intelligence'
print(value, type(value))

# %%
age = '20'
next_age = int(age) + 1
print(next_age)

# %% [markdown]
# ## 3. Python data structures for AI

# %%
agent_moves = ['left', 'forward', 'right']
student_names = {'S001': 'Aina', 'S002': 'Ben'}
unique_words = {'ai', 'python', 'ai', 'data'}
pixel = (255, 128, 0)
print(agent_moves)
print(student_names['S001'])
print(unique_words)
print(pixel)

# %% [markdown]
# ## 4. Tiny rule-based chatbot
# Add three new keywords and responses. Test an existing keyword and an unknown keyword.

# %%
responses = {
    'hello': 'Hi!',
    'bye': 'Goodbye!',
    'ai': 'AI is about intelligent action.'
}
user = input('You: ').strip().lower()
reply = responses.get(user, 'I do not know that yet.')
print(reply)

# %% [markdown]
# ## Reflection
# Write one sentence explaining which Python habit differs most from C or C++.
